# %%
import numpy as np

# %%
sample_mean = np.array([12.8, 10.9, 11.4, 14.2, 12.5, 13.6, 15, 9, 12.6])

# %%
add = sum(sample_mean)
add
# Out:
# np.float64(111.99999999999999)

# %%
n = len (sample_mean)
n
# Out:
# 9

# %%
population_mean = add/n
population_mean
# Out:
# np.float64(12.444444444444443)
