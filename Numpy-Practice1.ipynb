# %%
import numpy as np

# %%
arr1 = np.array([10, 20, 30, 40])
arr2 = np.array([[1, 2, 3], [4, 5, 6]])
arr3 = np.array([[[1, 2], [3, 4], [5, 6], [7, 8]]])

# %%
print(arr1.shape)
# Out:
# (4,)

# %%
print(arr2.shape)
# Out:
# (2, 3)

# %%
print(arr3.shape)
# Out:
# (1, 4, 2)

# %%
#Statistics 
marks = np.array([56, 78, 89, 45, 92, 88, 67, 74, 81, 90])

# %%
print("Mean:", np.mean(marks))
print("Median:", np.median(marks))
print("Standard Deviation:", np.std(marks))
print("Variance:", np.var(marks))
print("75th Percentile:", np.percentile(marks, 75))
# Out:
# Mean: 76.0
# Median: 79.5
# Standard Deviation: 14.966629547095765
# Variance: 224.0
# 75th Percentile: 88.75

# %%
temps = np.array([30, 32, 29, 35, 28, 33, 36, 31, 29, 34, 32, 30])
print("Average Temperature:", np.mean(temps))
print("Coldest Month Temperature:", np.min(temps))
print("Hottest Month Temperature:", np.max(temps))
print("Temperature Standard Deviation:", np.std(temps))
# Out:
# Average Temperature: 31.583333333333332
# Coldest Month Temperature: 28
# Hottest Month Temperature: 36
# Temperature Standard Deviation: 2.43099202430247

# %%
arr = np.array([10, 20, 30, 40, 50])
print(arr[0])
print(arr[-1])
print(arr[2])
# Out:
# 10
# 50
# 30

# %%
arr = np.array([10, 20, 30, 40, 50])
print(arr[0:4])
print(arr[1:5])
print(arr[::2])
print(arr[:4])
print(arr[2:4])
print(arr[2:])
# Out:
# [10 20 30 40]
# [20 30 40 50]
# [10 30 50]
# [10 20 30 40]
# [30 40]
# [30 40 50]

# %%
matrix = np.array([[10, 20, 30], 
                   [40, 50, 60], 
                   [70, 80, 90]])
print(matrix[0, 1])
print(matrix[2, -1])
# Out:
# 20
# 90

# %%
marks = np.array([45, 78, 90, 34, 67, 82, 95])
high_scores = marks[marks>60]
print(high_scores)
# Out:
# [78 90 67 82 95]

# %%
zero_arr = np.zeros((3, 3))
print(zero_arr)
# Out:
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [0. 0. 0.]]

# %%
ones_arr = np.ones((2, 4))
print(ones_arr)
# Out:
# [[1. 1. 1. 1.]
#  [1. 1. 1. 1.]]

# %%
evenly_spaced  = np.arange(1, 11, 2)
print(evenly_spaced)
# Out:
# [1 3 5 7 9]

# %%
random_arr = np.random.rand(3, 3)
print(random_arr)
# Out:
# [[0.29299939 0.51316623 0.28984832]
#  [0.30730291 0.85352883 0.93888261]
#  [0.96332802 0.46992355 0.69047886]]

# %%
arr = np.array([5, 10, 15, 20])
print(arr+5)
print(arr*2)
# Out:
# [10 15 20 25]
# [10 20 30 40]

# %%
arr2 = np.array([1, 2, 3, 4])
print(arr + arr2)
# Out:
# [ 6 12 18 24]

# %%
marks = np.array([45, 78, 90, 34, 67, 82, 95])
print("Mean:", np.mean(marks))
print("Median:", np.median(marks))
print("Standard Deviation:", np.std(marks))
print("Variance:", np.var(marks))
# Out:
# Mean: 70.14285714285714
# Median: 78.0
# Standard Deviation: 21.256451601663848
# Variance: 451.8367346938776

# %%
matrix = np.array([[1, 2, 3], [4, 5, 6]])
print(matrix)
print(matrix.shape)
# Out:
# [[1 2 3]
#  [4 5 6]]
# (2, 3)

# %%
A = np.array([[1, 2], [3, 4]])
B = np.array([[5, 6], [7, 8]])
print(A + B)
print(A - B)
print(A * B)
print("Transpose of A:", A.T)
# Out:
# [[ 6  8]
#  [10 12]]
# [[-4 -4]
#  [-4 -4]]
# [[ 5 12]
#  [21 32]]
# Transpose of A: [[1 3]
#  [2 4]]

# %%
result = A @ B
print(result)
# Out:
# [[19 22]
#  [43 50]]

# %%
dot = np.dot(A, B)
print(dot)
# Out:
# [[19 22]
#  [43 50]]

# %%
from numpy.linalg import det, inv
determinant = det(A)
print("Determinant of A:", determinant)
# Out:
# Determinant of A: -2.0000000000000004

# %%
inverse = inv(A)
print("Inverse of A:\n", inverse)
# Out:
# Inverse of A:
#  [[-2.   1. ]
#  [ 1.5 -0.5]]
